# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere are several approaches to extract the bucket name from an S3 URI:\n\n## Solution 1: Using String Methods (Simple)\n```python\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    return s3_uri.replace(\"s3://\", \"\").split(\"/\")[0]\n\n# Test\nprint(get_bucket_name(\"s3://my-bucket/path/to/file.txt\"))  # Output: my-bucket\n```\n\n## Solution 2: Using Regular Expressions (Robust)\n```python\nimport re\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using regex\"\"\"\n    match = re.match(r\"s3://([a-z0-9.-]+)\", s3_uri)\n    if match:\n        return match.group(1)\n    return None\n\n# Test\nprint(get_bucket_name(\"s3://my-bucket/path/to/file.txt\"))  # Output: my-bucket\n```\n\n## Solution 3: Using urllib (Most Robust)\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using urlparse\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc\n\n# Test\nprint(get_bucket_name(\"s3://my-bucket/path/to/file.txt\"))  # Output: my-bucket\n```\n\n## Solution 4: Using boto3 (For AWS Projects)\n```python\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    # Remove 's3://' prefix and split on first '/'\n    if s3_uri.startswith(\"s3://\"):\n        return s3_uri[5:].split(\"/\")[0]\n    return None\n\n# Test\nprint(get_bucket_name(\"s3://my-bucket/path/to/file.txt\"))  # Output: my-bucket\n```\n\n## Comprehensive Solution with Validation\n```python\ndef get_bucket_name(s3_uri):\n    \"\"\"\n    Extract and validate bucket name from S3 URI\n    \n    Args:\n        s3_uri (str): S3 URI in format 's3://bucket-name/path'\n    \n    Returns:\n        str: Bucket name or None if invalid\n    \n    Raises:\n        ValueError: If URI format is invalid\n    \"\"\"\n    if not isinstance(s3_uri, str):\n        raise ValueError(\"S3 URI must be a string\")\n    \n    if not s3_uri.startswith(\"s3://\"):\n        raise ValueError(\"S3 URI must start with 's3://'\")\n    \n    # Remove 's3://' and split by '/'\n    remainder = s3_uri[5:]\n    bucket = remainder.split(\"/\")[0]\n    \n    if not bucket:\n        raise ValueError(\"Bucket name is empty\")\n    \n    return bucket\n\n# Test cases\ntry:\n    print(get_bucket_name(\"s3://my-bucket/path/to/file.txt\"))  # my-bucket\n    print(get_bucket_name(\"s3://another-bucket/\"))               # another-bucket\n    print(get_bucket_name(\"s3://bucket\"))                        # bucket\nexcept ValueError as e:\n    print(f\"Error: {e}\")\n```\n\n## Recommendation\n\n- **Use Solution 1** for simple cases where you control the input\n- **Use Solution 3** for general-purpose parsing (most Pythonic)\n- **Use Solution 4** for clarity and explicit handling\n- **Use the comprehensive solution** for production code with validation\n\nAll solutions handle the basic case correctly. Choose based on your needs!",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket/path/to/file.txt') and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution provides good variety and includes appropriate error handling in the final example. However, there are technical inaccuracies in the regex pattern and incomplete validation against actual AWS S3 bucket naming rules. The recommendation to use urllib as 'most robust' is questionable since it provides no validation. The code is functional for typical cases but production use should include comprehensive AWS-compliant bucket name validation."
#   },
#   {
#     "output": "# AWS Lambda CloudFormation Template Snippet\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template with AWS Lambda function\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"MyLambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"MyBasicLambdaFunction\",\n        \"Runtime\": \"python3.11\",\n        \"Handler\": \"index.lambda_handler\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello from Lambda!'\\n    }\\n\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyLambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaFunctionName\": {\n      \"Description\": \"Name of the Lambda function\",\n      \"Value\": {\n        \"Ref\": \"MyLambdaFunction\"\n      }\n    }\n  }\n}\n```\n\n## Key Components Explained:\n\n| Component | Purpose |\n|-----------|---------|\n| **LambdaExecutionRole** | IAM role that grants Lambda permissions to execute and write logs to CloudWatch |\n| **Runtime** | `python3.11` - specifies the Python version (can be Node.js, Java, etc.) |\n| **Handler** | `index.lambda_handler` - entry point function in your code |\n| **Role** | ARN reference to the IAM execution role |\n| **Code** | Inline Python function (can also reference S3 bucket for larger code) |\n\n## Alternative Runtime Options:\n```json\n\"Runtime\": \"nodejs18.x\"  // or\n\"Runtime\": \"java11\"      // or\n\"Runtime\": \"go1.x\"       // or\n\"Runtime\": \"dotnet6\"\n```\n\nThis template creates a production-ready Lambda function with proper IAM permissions and CloudWatch logging capability.",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS Lambda function with basic configuration (runtime, handler, role ARN)",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution exceeds the task requirements in scope and documentation quality. While this makes it more production-ready and educational, it deviates from the 'snippet' request by including full template structure and inline code not specified in the task. The core requirement (Lambda function with runtime, handler, and role ARN configuration) is correctly implemented with proper CloudFormation syntax. The additional IAM role and outputs demonstrate best practices but weren't requested. For a basic configuration snippet, this is slightly over-engineered, though the documentation quality is excellent."
#   },
#   {
#     "output": "# AWS IAM Policy Action Extractor\n\n```python\nimport json\nfrom typing import List, Union\n\ndef extract_iam_actions(policy_json: str) -> List[str]:\n    \"\"\"\n    Extracts all 'Action' values from an AWS IAM policy JSON string.\n    \n    Args:\n        policy_json (str): A JSON string representing an AWS IAM policy\n        \n    Returns:\n        List[str]: A list of all Action values found in the policy\n        \n    Raises:\n        json.JSONDecodeError: If the input is not valid JSON\n        ValueError: If the input is not a valid IAM policy structure\n    \"\"\"\n    try:\n        policy = json.loads(policy_json)\n    except json.JSONDecodeError as e:\n        raise json.JSONDecodeError(f\"Invalid JSON: {e.msg}\", e.doc, e.pos)\n    \n    actions = []\n    \n    # Check if policy has Statement\n    if not isinstance(policy, dict) or 'Statement' not in policy:\n        raise ValueError(\"Invalid IAM policy: missing 'Statement' key\")\n    \n    statements = policy['Statement']\n    \n    # Handle case where Statement is a single dict instead of list\n    if isinstance(statements, dict):\n        statements = [statements]\n    \n    if not isinstance(statements, list):\n        raise ValueError(\"Invalid IAM policy: 'Statement' must be a list or dict\")\n    \n    # Extract actions from each statement\n    for statement in statements:\n        if isinstance(statement, dict) and 'Action' in statement:\n            action_value = statement['Action']\n            \n            # Action can be a string or a list of strings\n            if isinstance(action_value, str):\n                actions.append(action_value)\n            elif isinstance(action_value, list):\n                actions.extend(action_value)\n    \n    return actions\n\n\n# Example usage and test cases\nif __name__ == \"__main__\":\n    # Test case 1: Single action as string\n    policy1 = \"\"\"\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::mybucket/*\"\n            }\n        ]\n    }\n    \"\"\"\n    print(\"Test 1 - Single action:\")\n    print(extract_iam_actions(policy1))\n    # Output: ['s3:GetObject']\n    \n    # Test case 2: Multiple actions as list\n    policy2 = \"\"\"\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\n                    \"s3:GetObject\",\n                    \"s3:PutObject\",\n                    \"s3:DeleteObject\"\n                ],\n                \"Resource\": \"arn:aws:s3:::mybucket/*\"\n            }\n        ]\n    }\n    \"\"\"\n    print(\"\\nTest 2 - Multiple actions in list:\")\n    print(extract_iam_actions(policy2))\n    # Output: ['s3:GetObject', 's3:PutObject', 's3:DeleteObject']\n    \n    # Test case 3: Multiple statements with mixed action types\n    policy3 = \"\"\"\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"ec2:DescribeInstances\",\n                \"Resource\": \"*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\n                    \"iam:GetUser\",\n                    \"iam:ListUsers\"\n                ],\n                \"Resource\": \"*\"\n            },\n            {\n                \"Effect\": \"Deny\",\n                \"Action\": \"iam:DeleteUser\",\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    \"\"\"\n    print(\"\\nTest 3 - Multiple statements:\")\n    print(extract_iam_actions(policy3))\n    # Output: ['ec2:DescribeInstances', 'iam:GetUser', 'iam:",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM policy JSON string and returns a list of all 'Action' values defined in it",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly addresses the core task of extracting Action values from IAM policies with proper type handling and validation. The code is readable and well-tested. However, it lacks robustness for edge cases like wildcard actions, doesn't enforce IAM policy structure requirements comprehensively, and has minor error handling inefficiencies. For production use, additional validation of required IAM policy fields and handling of nested/wildcard scenarios would be beneficial."
#   }
# ]
